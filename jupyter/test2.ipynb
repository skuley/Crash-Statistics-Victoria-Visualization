# %%
import matplotlib.pyplot as plot
values = {'02.49.00': 1,
 '04.04.00': 1,
 '07.09.00': 1,
 '09.00.00': 1,
 '09.45.00': 1,
 '10.50.00': 1,
 '11.00.00': 1,
 '11.30.00': 1,
 '12.15.00': 1,
 '12.20.00': 1,
 '12.30.00': 1,
 '13.05.00': 1,
 '14.34.00': 1,
 '15.10.00': 1,
 '15.11.00': 1,
 '19.10.00': 1,
 '20.50.00': 1,
 '22.00.00': 1}
plot.bar(values.keys(), values.values(), align='center')
# Out:
# <BarContainer object of 18 artists>
